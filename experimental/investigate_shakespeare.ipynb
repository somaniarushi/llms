# %%
from pathlib import Path

# %%
SHAKESPEARE_TXT = Path('data/shakespeare.txt')

# %%
with SHAKESPEARE_TXT.open("r", encoding="utf-8") as f:
    text = f.read()
# Out:
#   Cell In[2], line 1
#     with SHAKESPEARE_TXT.open("r", encoding=) as f:
#                              ^
# SyntaxError: expected ':'
